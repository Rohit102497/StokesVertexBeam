# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
import copy
import sklearn
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %%
filename = "/StokesVertexBeam/results/Design3/densenet.data"

# %%
def comp_confmat(actual, predicted):

    # extract the different classes
    classes = np.unique(actual)

    # initialize the confusion matrix
    confmat = np.zeros((len(classes), len(classes)))

    # loop across the different combinations of actual / predicted classes
    for i in range(len(classes)):
        for j in range(len(classes)):

           # count the number of instances in each combination of actual / predicted classes
           confmat[i, j] = np.sum((actual == classes[i]) & (predicted == classes[j]))

    return confmat

# %%
# open a file, where you stored the pickled data
file = open(filename, 'rb')
# dump information to that file
data = pickle.load(file)
data_an = copy.deepcopy(data)
plt.plot(data['Train_loss'], label = 'Train Loss')
plt.plot(data['Val_loss'], label = 'Validation Loss')
#adding text inside the plot
plt.text(35, 1.9, 'Exp acc  = ' + str(round(data['experimental_acc'], 4)), fontsize = 10)
plt.text(35, 1.7, 'Test acc  = ' + str(round(data['test_acc'], 4)), fontsize = 10)
plt.text(35, 1.5, 'Val acc  = ' + str(round(data['Val_acc'][49].item(), 4)), fontsize = 10)
plt.text(35, 1.3, 'Train acc  = ' + str(round(data['Train_acc'][49].item(), 4)), fontsize = 10)
plt.legend()
plt.title("Alexnet, Exp 1, BS 8, lr 0.001, momentum 0.9, epochs 50" )
print(round(data['Train_loss'][49], 4), round(data['Val_loss'][49], 4))
print(round(data['experimental_acc'], 4), round(data['test_acc'], 4), 
    round(data['Val_acc'][49].item(), 4), round(data['Train_acc'][49].item(), 4))
# Out:
# 0.1395 0.1915
# 0.94 0.95 0.9222 0.9471

# %%
# open a file, where you stored the pickled data
file = open(filename, 'rb')
# dump information to that file
data = pickle.load(file)
plt.plot(data['Train_loss'], label = 'Train Loss')
plt.plot(data['Val_loss'], label = 'Validation Loss')
#adding text inside the plot
plt.text(35, 1.9, 'Exp acc  = ' + str(round(data['experimental_acc'], 4)), fontsize = 10)
plt.text(35, 1.7, 'Test acc  = ' + str(round(data['test_acc'], 4)), fontsize = 10)
plt.text(35, 1.5, 'Val acc  = ' + str(round(data['Val_acc'][49].item(), 4)), fontsize = 10)
plt.text(35, 1.3, 'Train acc  = ' + str(round(data['Train_acc'][49].item(), 4)), fontsize = 10)
plt.legend()
plt.title("Alexnet, Exp 2, BS 8, lr 0.01, momentum 0.9, epochs 50" )
print(round(data['Train_loss'][49], 4), round(data['Val_loss'][49], 4))
print(round(data['experimental_acc'], 4), round(data['test_acc'], 4), 
    round(data['Val_acc'][49].item(), 4), round(data['Train_acc'][49].item(), 4))
# Out:
# 2.7111 2.7105
# 0.5867 0.75 0.0667 0.0657

# %%
# open a file, where you stored the pickled data
file = open(filename, 'rb')
# dump information to that file
data = pickle.load(file)
data_rn = copy.deepcopy(data)
plt.plot(data['Train_loss'], label = 'Train Loss')
plt.plot(data['Val_loss'], label = 'Validation Loss')
#adding text inside the plot
plt.text(35, .9, 'Exp acc  = ' + str(round(data['experimental_acc'], 4)), fontsize = 10)
plt.text(35, .7, 'Test acc  = ' + str(round(data['test_acc'], 4)), fontsize = 10)
plt.text(35, .5, 'Val acc  = ' + str(round(data['Val_acc'][49].item(), 4)), fontsize = 10)
plt.text(35, .3, 'Train acc  = ' + str(round(data['Train_acc'][49].item(), 4)), fontsize = 10)
plt.legend()
plt.title("Resnet, Exp 1, BS 8, lr 0.001, momentum 0.9, epochs 50" )
print(round(data['Train_loss'][49], 4), round(data['Val_loss'][49], 4))
print(round(data['experimental_acc'], 4), round(data['test_acc'], 4), 
    round(data['Val_acc'][49].item(), 4), round(data['Train_acc'][49].item(), 4))
# Out:
# 0.0586 0.0553
# 0.9867 0.9767 0.9778 0.9781

# %%
# open a file, where you stored the pickled data
file = open(filename, 'rb')
# dump information to that file
data = pickle.load(file)
plt.plot(data['Train_loss'], label = 'Train Loss')
plt.plot(data['Val_loss'], label = 'Validation Loss')
#adding text inside the plot
plt.text(35, .9, 'Exp acc  = ' + str(round(data['experimental_acc'], 4)), fontsize = 10)
plt.text(35, .7, 'Test acc  = ' + str(round(data['test_acc'], 4)), fontsize = 10)
plt.text(35, .5, 'Val acc  = ' + str(round(data['Val_acc'][49].item(), 4)), fontsize = 10)
plt.text(35, .3, 'Train acc  = ' + str(round(data['Train_acc'][49].item(), 4)), fontsize = 10)
plt.legend()
plt.title("Resnet, Exp 2, BS 8, lr 0.01, momentum 0.9, epochs 50" )
print(round(data['Train_loss'][49], 4), round(data['Val_loss'][49], 4))
print(round(data['experimental_acc'], 4), round(data['test_acc'], 4), 
    round(data['Val_acc'][49].item(), 4), round(data['Train_acc'][49].item(), 4))
# Out:
# 0.051 0.0276
# 0.9333 0.9707 0.9889 0.9815

# %%
# open a file, where you stored the pickled data
file = open(filename, 'rb')
# dump information to that file
data = pickle.load(file)
data_sn = copy.deepcopy(data)
plt.plot(data['Train_loss'], label = 'Train Loss')
plt.plot(data['Val_loss'], label = 'Validation Loss')
#adding text inside the plot
plt.text(35, 1.9, 'Exp acc  = ' + str(round(data['experimental_acc'], 4)), fontsize = 10)
plt.text(35, 1.7, 'Test acc  = ' + str(round(data['test_acc'], 4)), fontsize = 10)
plt.text(35, 1.5, 'Val acc  = ' + str(round(data['Val_acc'][49].item(), 4)), fontsize = 10)
plt.text(35, 1.3, 'Train acc  = ' + str(round(data['Train_acc'][49].item(), 4)), fontsize = 10)
plt.legend()
plt.title("Squeezenet, Exp 1, BS 8, lr 0.001, momentum 0.9, epochs 50" )
print(round(data['Train_loss'][49], 4), round(data['Val_loss'][49], 4))
print(round(data['experimental_acc'], 4), round(data['test_acc'], 4), 
    round(data['Val_acc'][49].item(), 4), round(data['Train_acc'][49].item(), 4))
# Out:
# 0.2506 0.2804
# 0.88 0.858 0.9111 0.9072

# %%
# open a file, where you stored the pickled data
file = open(filename, 'rb')
# dump information to that file
data = pickle.load(file)
plt.plot(data['Train_loss'], label = 'Train Loss')
plt.plot(data['Val_loss'], label = 'Validation Loss')
#adding text inside the plot
# plt.text(0,0 , 'Exp acc  = ' + str(round(data['experimental_acc'], 4)), fontsize = 10)
# plt.text(35, 1.7, 'Test acc  = ' + str(round(data['test_acc'], 4)), fontsize = 10)
# plt.text(35, 1.5, 'Val acc  = ' + str(round(data['Val_acc'][49].item(), 4)), fontsize = 10)
# plt.text(35, 1.3, 'Train acc  = ' + str(round(data['Train_acc'][49].item(), 4)), fontsize = 10)
plt.legend()
plt.title("Squeezenet, Exp 2, BS 8, lr 0.01, momentum 0.9, epochs 50" )
print(round(data['Train_loss'][49], 4), round(data['Val_loss'][49], 4))
print(round(data['experimental_acc'], 4), round(data['test_acc'], 4), 
    round(data['Val_acc'][49].item(), 4), round(data['Train_acc'][49].item(), 4))
# Out:
# 2.7081 2.7081
# 0.0667 0.0667 0.0667 0.0667

# %%
# open a file, where you stored the pickled data
file = open(filename, 'rb')
# dump information to that file
data = pickle.load(file)
data_vgg = copy.deepcopy(data)
plt.plot(data['Train_loss'], label = 'Train Loss')
plt.plot(data['Val_loss'], label = 'Validation Loss')
#adding text inside the plot
plt.text(35, 1.5, 'Exp acc  = ' + str(round(data['experimental_acc'], 4)), fontsize = 10)
plt.text(35, 1.3, 'Test acc  = ' + str(round(data['test_acc'], 4)), fontsize = 10)
plt.text(35, 1.1, 'Val acc  = ' + str(round(data['Val_acc'][49].item(), 4)), fontsize = 10)
plt.text(35, .9, 'Train acc  = ' + str(round(data['Train_acc'][49].item(), 4)), fontsize = 10)
plt.legend()
plt.title("VGG, Exp 1, BS 8, lr 0.001, momentum 0.9, epochs 50" )
print(round(data['Train_loss'][49], 4), round(data['Val_loss'][49], 4))
print(round(data['experimental_acc'], 4), round(data['test_acc'], 4), 
    round(data['Val_acc'][49].item(), 4), round(data['Train_acc'][49].item(), 4))
# Out:
# 0.1099 0.0944
# 0.9333 0.9573 0.9778 0.9585

# %%
# open a file, where you stored the pickled data
file = open(filename, 'rb')
# dump information to that file
data = pickle.load(file)
plt.plot(data['Train_loss'], label = 'Train Loss')
plt.plot(data['Val_loss'], label = 'Validation Loss')
#adding text inside the plot
plt.text(35, 1.5, 'Exp acc  = ' + str(round(data['experimental_acc'], 4)), fontsize = 10)
plt.text(35, 1.3, 'Test acc  = ' + str(round(data['test_acc'], 4)), fontsize = 10)
plt.text(35, 1.1, 'Val acc  = ' + str(round(data['Val_acc'][49].item(), 4)), fontsize = 10)
plt.text(35, .9, 'Train acc  = ' + str(round(data['Train_acc'][49].item(), 4)), fontsize = 10)
plt.legend()
plt.title("VGG, Exp 2, BS 8, lr 0.001, momentum 0.9, epochs 50" )
print(round(data['Train_loss'][49], 4), round(data['Val_loss'][49], 4))
print(round(data['experimental_acc'], 4), round(data['test_acc'], 4), 
    round(data['Val_acc'][49].item(), 4), round(data['Train_acc'][49].item(), 4))
# Out:
# 0.1 0.1529
# 0.9667 0.968 0.9444 0.9629

# %%
# open a file, where you stored the pickled data
file = open(filename, 'rb')
# dump information to that file
data = pickle.load(file)
data_dn = copy.deepcopy(data)
plt.plot(data['Train_loss'], label = 'Train Loss')
plt.plot(data['Val_loss'], label = 'Validation Loss')
#adding text inside the plot
plt.text(35, 1.4, 'Exp acc  = ' + str(round(data['experimental_acc'], 4)), fontsize = 10)
plt.text(35, 1.3, 'Test acc  = ' + str(round(data['test_acc'], 4)), fontsize = 10)
plt.text(35, 1.2, 'Val acc  = ' + str(round(data['Val_acc'][49].item(), 4)), fontsize = 10)
plt.text(35, 1.1, 'Train acc  = ' + str(round(data['Train_acc'][49].item(), 4)), fontsize = 10)
plt.legend()
plt.title("Densenet, Exp 1, BS 8, lr 0.001, momentum 0.9, epochs 50" )
print(round(data['Train_loss'][49], 4), round(data['Val_loss'][49], 4))
print(round(data['experimental_acc'], 4), round(data['test_acc'], 4), 
    round(data['Val_acc'][49].item(), 4), round(data['Train_acc'][49].item(), 4))
# Out:
# 0.05 0.0043
# 0.96 0.9833 1.0 0.9836

# %%
# open a file, where you stored the pickled data
file = open(filename, 'rb')
# dump information to that file
data = pickle.load(file)
plt.plot(data['Train_loss'], label = 'Train Loss')
plt.plot(data['Val_loss'], label = 'Validation Loss')
#adding text inside the plot
plt.text(35, 1, 'Exp acc  = ' + str(round(data['experimental_acc'], 4)), fontsize = 10)
plt.text(35, .8, 'Test acc  = ' + str(round(data['test_acc'], 4)), fontsize = 10)
plt.text(35, .6, 'Val acc  = ' + str(round(data['Val_acc'][49].item(), 4)), fontsize = 10)
plt.text(35, .4, 'Train acc  = ' + str(round(data['Train_acc'][49].item(), 4)), fontsize = 10)
plt.legend()
plt.title("Densenet, Exp 2, BS 8, lr 0.01, momentum 0.9, epochs 50" )
print(round(data['Train_loss'][49], 4), round(data['Val_loss'][49], 4))
print(round(data['experimental_acc'], 4), round(data['test_acc'], 4), 
    round(data['Val_acc'][49].item(), 4), round(data['Train_acc'][49].item(), 4))
# Out:
# 0.0455 0.0592
# 0.98 0.98 0.9778 0.984

# %%
markers_on = [5, 10, 15, 20, 25, 30, 35, 40, 45]
fig, (ax1, ax2) = plt.subplots(1, 2, sharey='row', figsize = (10, 5))
# fig.suptitle('Horizontally stacked subplots')
ax1.plot(data_rn['Train_loss'], label = 'Train Loss')
ax1.plot(data_rn['Val_loss'], label = 'Validation Loss')
ax1.tick_params(labelsize=12)
ax1.title.set_text('(a) ResNet-18')
ax1.title.set_size(12)
ax2.plot(data_dn['Train_loss'], label = 'Training Loss')
ax2.plot(data_dn['Val_loss'], label = 'Validation Loss')
ax2.title.set_text('(b) DenseNet')
ax2.title.set_size(12)
ax2.tick_params(labelsize=12)
ax1.set_ylabel("Loss", size = 12)
ax1.set_xlabel("Epochs", size = 12)
ax2.set_xlabel("Epochs", size = 12)
plt.legend(prop={'size': 12})
plt.savefig("Loss_Resnet_Densenet_Design3.png")

# %%
cm = confusion_matrix(data_rn['experimental_actual_label'], data_rn['experimental_prediction'])
cm_display = ConfusionMatrixDisplay(cm).plot()
save_filename = '/StokesVertexBeam/results/Design3/confusion_matrix_resnet_experimental_design3.png'
cm_display.figure_.savefig(save_filename)

# %%
cm = confusion_matrix(data_rn['test_actual_label'], data_rn['test_prediction'])
cm_display = ConfusionMatrixDisplay(cm).plot()
save_filename = '/StokesVertexBeam/results/Design3/confusion_matrix_resnet_experimental_design3.png'
cm_display.figure_.savefig(save_filename)

# %%
cm = confusion_matrix(data_dn['experimental_actual_label'], data_dn['experimental_prediction'])
cm_display = ConfusionMatrixDisplay(cm).plot()
save_filename = '/StokesVertexBeam/results/Design3/confusion_matrix_resnet_experimental_design3.png'
cm_display.figure_.savefig(save_filename)

# %%
cm = confusion_matrix(data_dn['test_actual_label'], data_dn['test_prediction'])
cm_display = ConfusionMatrixDisplay(cm).plot()
save_filename = '/StokesVertexBeam/results/Design3/confusion_matrix_resnet_experimental_design3.png'
cm_display.figure_.savefig(save_filename)
